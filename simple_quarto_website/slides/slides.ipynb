# %% [markdown]
# ## Slide 1
# Lorem ipsum lorem ipsum [@daly1999].
#
# ## Slide 2
# ![](images/bichonfrise.png)
# ![](images/blackcat.png)

# %%
##Slide 3

# %%
import matplotlib.pyplot as plt

plt.plot([0,1,2,3],[0,1,2,3])
plt.title("Plot")
plt.show()
